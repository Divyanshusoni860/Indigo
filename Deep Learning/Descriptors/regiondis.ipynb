# %% [markdown]
# Intensity Descriptors

# %% [markdown]
# Importing Lib

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Loading and Viewing an color image

# %%
img_path = "D:/indigo py/data/photos/cars/bmw.jpg"
clr_img = cv.imread(img_path)
img_rgb = cv.cvtColor(clr_img, cv.COLOR_BGR2RGB)
    
plt.imshow(img_rgb)
plt.axis('off')
plt.show()
img = cv.imread("path/to/image.jpg")  # no flag

print(clr_img.shape)
# Out:
# (2760, 4912, 3)

# %% [markdown]
# Loading a gray img

# %%
img_path_g = "D:/indigo py/data/photos/baw/bulb.jpg"
gry_img = cv.imread(img_path_g)

plt.imshow(gry_img)
plt.axis('off')
plt.show()
img = cv.imread("path/to/image.jpg")  # no flag

print(gry_img.shape)
# Out:
# (4179, 2786, 3)

# %% [markdown]
# it still has 3 channels, to print actual gray;

# %%
img_path_g = "D:/indigo py/data/photos/baw/street.jpg"
gry_img = cv.imread(img_path_g,cv.IMREAD_GRAYSCALE)

plt.imshow(gry_img,cmap="gray")
plt.axis('off')
plt.show()
img = cv.imread("path/to/image.jpg")  # no flag

print(gry_img.shape)
# Out:
# (6000, 4000)

# %% [markdown]
# Plotting Intensity Dis Hist

# %%
hist = cv.calcHist([gry_img], [0], None, [256], [0, 256])

plt.plot(hist)
plt.title('Grayscale Histogram')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# for color image with 3 channels

# %%
channels = ('b', 'g', 'r')

# Plot each channel
for i, col in enumerate(channels):
    hist = cv.calcHist([img_rgb], [i], None, [256], [0, 256])
    plt.plot(hist, color=col)
    plt.xlim([0, 256])

plt.title('Color Image Histogram (BGR channels)')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.show()
